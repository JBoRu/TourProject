# %%
from selenium import webdriver
import time
from selenium.webdriver.common.action_chains import ActionChains

# %%
driver = webdriver.Chrome("./chromedriver")
driver.maximize_window()
driver.get("https://blog.csdn.net/weixin_43684713/article/details/90411306")
# data = driver.find_elements_by_xpath("//li[@data-type='blog']")
# # print(data)

# %%
content = driver.find_element_by_xpath('//article[@class="baidu_pl"]')

# %%
content_html = content.get_attribute('innerHTML')

# %%
print(content_html)
# Out:
#     <div id="article_content" class="article_content clearfix csdn-tracking-statistics" data-pid="blog" data-mod="popu_307" data-dsm="post" style="height: 295.5px; overflow: hidden;">
#             <link rel="stylesheet" href="https://csdnimg.cn/release/phoenix/template/css/ck_htmledit_views-f57960eb32.css">
#                               <link rel="stylesheet" href="https://csdnimg.cn/release/phoenix/template/css/ck_htmledit_views-f57960eb32.css">
#           <div class="htmledit_views" id="content_views">
#             <p>&nbsp;<strong>DOM树</strong></p>
#
# <p>&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;<img alt="" class="has" height="205" src="https://img-blog.csdnimg.cn/20190521173024725.png?x-oss-process=image/watermark,type_ZmFuZ3poZW5naGVpdGk,shadow_10,text_aHR0cHM6Ly9ibG9nLmNzZG4ubmV0L3dlaXhpbl80MzY4NDcxMw==,size_16,color_FFFFFF,t_70" width="485"></p>
#
# ...

# %%
# result = driver.find_elements_by_xpath("//li[@data-type='blog']//dd[@class='read_num']/a")
# print(result[0].get_attribute("href"))

# %%
ac = driver.find_elements_by_xpath("//a[@id='btn-readmore']")[0]
ActionChains(driver).move_to_element(ac).click(ac).perform()
